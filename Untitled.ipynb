# %%
# warnings
import warnings
warnings.filterwarnings('ignore')


# Data manipulation
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)


# visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
sns.set(style="whitegrid", color_codes=True)

# %%
# load the data 
amazon_df = pd.read_csv('Amazon_Unlocked_Mobile.csv')

# %%
amazon_df.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
amazon_df.tail()
# Out:
#                                              Product Name Brand Name  Price  \
# 413835  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413836  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413837  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413838  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413839  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
#
#         Rating                                            Reviews  \
# 413835       5                     another great deal great price
# 413836       3                                                 Ok
# 413837       5        Passes every drop test onto porcelain tile!
# 413838       3  I returned it because it did not meet my needs...
# 413839       4  Only downside is that apparently Verizon no lo...
#
#         Review Votes
# 413835           0.0
# 413836           0.0
# 413837           0.0
# ...

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413840 entries, 0 to 413839
# Data columns (total 6 columns):
# Product Name    413840 non-null object
# Brand Name      348669 non-null object
# Price           407907 non-null float64
# Rating          413840 non-null int64
# Reviews         413778 non-null object
# Review Votes    401544 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 18.9+ MB

# %%
amazon_df.columns
# Out:
# Index(['Product Name', 'Brand Name', 'Price', 'Rating', 'Reviews',
#        'Review Votes'],
#       dtype='object')

# %%
amazon_df.shape
# Out:
# (413840, 6)

# %%
reviews= amazon_df['Reviews']
len(reviews)
# Out:
# 413840

# %%
Brand_name = amazon_df['Brand Name'].str.upper()
Brand_name.value_counts().head()
# Out:
# SAMSUNG       68720
# BLU           63256
# APPLE         58187
# LG            22423
# BLACKBERRY    17929
# Name: Brand Name, dtype: int64

# %%
Price = amazon_df['Price']
Price.mean()
# Out:
# 226.86715538100597

# %%
Price.median()
# Out:
# 144.71

# %%
# %time
table=pd.pivot_table(amazon_df,
                    values = ['Price'],
                    index = ['Brand Name'],
                    columns = [],
                    aggfunc = [np.mean, np.median],
                    margins = True)
table
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 14.1 µs
#                                                           mean   median
#                                                          Price    Price
# Brand Name
# AMM Global Enterprises                               29.990000   29.990
# ARGOM TECH                                          111.720000  111.720
# ASUS                                                261.808137  280.980
# ASUS Computers                                      229.000000  229.000
# AT&T                                                  3.990000    3.990
# ATT                                                   2.290000    2.290
# Acer                                                 60.019091   34.950
# Aeku                                                 79.265000   79.265
# AeroAntenna                                         225.000000  225.000
# Alcatel                                             150.536103  129.000
# ...

# %%
customer_ratings=amazon_df.groupby(
    'Brand Name'
).Rating.agg(
    ['count', 'min', 'max']
).sort_values(
    'count', ascending = False
)
customer_ratings.head()
# Out:
#             count  min  max
# Brand Name
# Samsung     65747    1    5
# BLU         63248    1    5
# Apple       58186    1    5
# LG          22417    1    5
# BlackBerry  16872    1    5
